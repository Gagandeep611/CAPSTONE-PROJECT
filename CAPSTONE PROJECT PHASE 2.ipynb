# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r'C:\data science assesment answere\data science question/Book2.xlsx')
df
# Out:
#               STATE/UT  YEAR  RURAL POPULATION  URBAN POPULATION  \
# 0       ANDHRA PRADESH  2001          55401067          20808940
# 1    ARUNACHAL PRADESH  2001            870087            227881
# 2                ASSAM  2001          23216288           3439240
# 3                BIHAR  2001          74316709           8681800
# 4         CHHATTISGARH  2001          16648056           4185747
# ..                 ...   ...               ...               ...
# 451              DELHI  2012            944727          12905780
# 452        LAKSHADWEEP  2012             12165             52642
# 453         PUDUCHERRY  2012            401202            870273
# 454        TOTAL (UTs)  2012           1866226          15379428
# 455  TOTAL (ALL-INDIA)  2012         845210878         382343354
#
#      LITRACY RATE  AREA(km2)
# 0          0.6050     162968
# 1          0.5430      83743
# 2          0.6330      78438
# 3          0.4700      94163
# 4          0.6470     135192
# ...

# %%
df1=pd.read_csv(r'C:\data science assesment answere\data science question/17_Crime_by_place_of_occurrence_2001_2012.csv')
df1
# Out:
#               STATE/UT  YEAR  RESIDENTIAL PREMISES - Dacoity  \
# 0       ANDHRA PRADESH  2001                             100
# 1    ARUNACHAL PRADESH  2001                               9
# 2                ASSAM  2001                             381
# 3                BIHAR  2001                             818
# 4         CHHATTISGARH  2001                              54
# ..                 ...   ...                             ...
# 451              DELHI  2012                              10
# 452        LAKSHADWEEP  2012                               0
# 453         PUDUCHERRY  2012                               1
# 454        TOTAL (UTs)  2012                              11
# 455  TOTAL (ALL-INDIA)  2012                            1288
#
#      RESIDENTIAL PREMISES - Robbery  RESIDENTIAL PREMISES - Burglary  \
# 0                               177                             5158
# 1                                26                               99
# ...

# %%
data=pd.merge(df,df1)
data
# Out:
#               STATE/UT  YEAR  RURAL POPULATION  URBAN POPULATION  \
# 0       ANDHRA PRADESH  2001          55401067          20808940
# 1    ARUNACHAL PRADESH  2001            870087            227881
# 2                ASSAM  2001          23216288           3439240
# 3                BIHAR  2001          74316709           8681800
# 4         CHHATTISGARH  2001          16648056           4185747
# ..                 ...   ...               ...               ...
# 453              DELHI  2012            944727          12905780
# 454        LAKSHADWEEP  2012             12165             52642
# 455         PUDUCHERRY  2012            401202            870273
# 456        TOTAL (UTs)  2012           1866226          15379428
# 457  TOTAL (ALL-INDIA)  2012         845210878         382343354
#
#      LITRACY RATE  AREA(km2)  RESIDENTIAL PREMISES - Dacoity  \
# 0          0.6050     162968                             100
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 458 entries, 0 to 457
# Data columns (total 40 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   STATE/UT                              458 non-null    object
#  1   YEAR                                  458 non-null    int64
#  2   RURAL POPULATION                      458 non-null    int64
#  3   URBAN POPULATION                      458 non-null    int64
#  4   LITRACY RATE                          458 non-null    float64
#  5   AREA(km2)                             458 non-null    int64
#  6   RESIDENTIAL PREMISES - Dacoity        458 non-null    int64
#  7   RESIDENTIAL PREMISES - Robbery        458 non-null    int64
#  8   RESIDENTIAL PREMISES - Burglary       458 non-null    int64
#  9   RESIDENTIAL PREMISES - Theft          458 non-null    int64
#  10  HIGHWAYS - Dacoity                    458 non-null    int64
# ...

# %%
for i in data.columns:
    print(data[i].value_counts())
    print('\n')
# Out:
# DAMAN & DIU          15
# ANDHRA PRADESH       12
# TOTAL (STATES)       12
# RAJASTHAN            12
# SIKKIM               12
# TAMIL NADU           12
# UTTAR PRADESH        12
# UTTARAKHAND          12
# WEST BENGAL          12
# A & N ISLANDS        12
# ARUNACHAL PRADESH    12
# CHANDIGARH           12
# D & N HAVELI         12
# DELHI                12
# LAKSHADWEEP          12
# PUDUCHERRY           12
# TOTAL (UTs)          12
# PUNJAB               12
# ODISHA               12
# NAGALAND             12
# JAMMU & KASHMIR      12
# ASSAM                12
# BIHAR                12
# CHHATTISGARH         12
# GOA                  12
# GUJARAT              12
# HARYANA              12
# HIMACHAL PRADESH     12
# JHARKHAND            12
# MIZORAM              12
# KARNATAKA            12
# KERALA               12
# MADHYA PRADESH       12
# MAHARASHTRA          12
# MANIPUR              12
# MEGHALAYA            12
# TOTAL (ALL-INDIA)    12
# TRIPURA              11
# ...

# %%
data.drop(['Unnamed: 34','SCSCS'],axis=1,inplace=True)
data
# Out:
#               STATE/UT  YEAR  RURAL POPULATION  URBAN POPULATION  \
# 0       ANDHRA PRADESH  2001          55401067          20808940
# 1    ARUNACHAL PRADESH  2001            870087            227881
# 2                ASSAM  2001          23216288           3439240
# 3                BIHAR  2001          74316709           8681800
# 4         CHHATTISGARH  2001          16648056           4185747
# ..                 ...   ...               ...               ...
# 453              DELHI  2012            944727          12905780
# 454        LAKSHADWEEP  2012             12165             52642
# 455         PUDUCHERRY  2012            401202            870273
# 456        TOTAL (UTs)  2012           1866226          15379428
# 457  TOTAL (ALL-INDIA)  2012         845210878         382343354
#
#      LITRACY RATE  AREA(km2)  RESIDENTIAL PREMISES - Dacoity  \
# 0          0.6050     162968                             100
# ...

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='LITRACY RATE',y='TOTAL - Theft',data=data)
# Out:
# <AxesSubplot:xlabel='LITRACY RATE', ylabel='TOTAL - Theft'>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='LITRACY RATE',y='TOTAL - Robbery',data=data)
# Out:
# <AxesSubplot:xlabel='LITRACY RATE', ylabel='TOTAL - Robbery'>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='LITRACY RATE',y='TOTAL - Dacoity',data=data)
# Out:
# <AxesSubplot:xlabel='LITRACY RATE', ylabel='TOTAL - Dacoity'>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='LITRACY RATE',y='TOTAL - Burglary',data=data)
# Out:
# <AxesSubplot:xlabel='LITRACY RATE', ylabel='TOTAL - Burglary'>

# %% [markdown]
# # observation
# IN THE 4 OF THE GRAPH WE CAN CLEARLY SAY THAT WHEN THERE IS LITRACY RATE BETWEEN 0-5
# TOTAL THEFT IS SLIGHTLY ABOVE 50000
# TOTAL ROBERRY IS AROUND 5000
# TOTAL DECAOITY IS BETWEEN 1000-2000
# TOTAL BURGLARY IS AROUND 20000
# FROM THE ABOVE OBSERVATION WE CAN CLEARLY SAY THAT THEFT IS HIGHEST AS COMPARED TO OTHER GRAPH
# ALSO WE OBSERVE THAT AS THE LITRACY RATE INCREASES THE CRIME ALSO INCREASES

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='HIGHWAYS - Dacoity',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='HIGHWAYS - Dacoity', ylabel='STATE/UT'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='HIGHWAYS - Robbery',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='HIGHWAYS - Robbery', ylabel='STATE/UT'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='HIGHWAYS - Theft',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='HIGHWAYS - Theft', ylabel='STATE/UT'>

# %% [markdown]
# # observation
# IN THEABOVE 3 GRAPH WE CAN SEE THAT MAXIMUM CRIME HAPPEN ON THE HIGHWAY IN UTTAR PRADESH BETWEEN 8000-10000
# ALSO WE CAN SAY THAT IN ALL THE 3 GRAPH THE CRIMES HAPPEN IN THE STATES ARE MORE AS COMPARED TO THE UNION TERRITORIES

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='RAILWAYS - Dacoity',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='RAILWAYS - Dacoity', ylabel='STATE/UT'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='RAILWAYS - Robbery',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='RAILWAYS - Robbery', ylabel='STATE/UT'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='RAILWAYS - Burglary',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='RAILWAYS - Burglary', ylabel='STATE/UT'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='RAILWAYS - Theft',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='RAILWAYS - Theft', ylabel='STATE/UT'>

# %% [markdown]
# # OBSERVATION
# IN THE ABOVE 4 GRAPH THERE ARE MANY OBSERVATION
# 1.ACCORDING TO THE RAILWATY DECOTI GRAPH BIHAR HAS THE MAXIMUM NUMBER OF DECATY AS COMPARED TO THE OTHER STATE
# 2.ACCORDING TO THE RAILWAY ROBBERY GRAPH MAHARASHTRA HAS MAXIMUM NUMBER OF ROBBERY AS COMPARED TO THE OTHER STATE
# 3.ACCORDING TO THE RAILWAY BURGLARY GRAPH ASSAM HAS MAXIMUM NUMBER OF BURGLARY AS COMPARED TO THE OTHER STATE
# 4.ACCORDING TO THE RAILWAY THEFT GRAPH MAHARASHTRA HAS MAXIMUM NYMBER OF THEFT AS COMPARED TO THE OTHER STATE
# ALSO WE CAN SAY THAT IN ALL THE 4 GRAPH THE CRIMES HAPPEN IN THE STATES ARE MORE AS COMPARED TO THE UNION TERRITORIES

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='BANKS - Dacoity',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='BANKS - Dacoity', ylabel='STATE/UT'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='BANKS - Robbery',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='BANKS - Robbery', ylabel='STATE/UT'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='BANKS - Burglary',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='BANKS - Burglary', ylabel='STATE/UT'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='BANKS - Theft',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='BANKS - Theft', ylabel='STATE/UT'>

# %% [markdown]
# # OBSERVATION
# IN THE ABOVE 4 GRAPH THERE ARE MANY OBSERVATION
# 1.ACCORDING TO THE BANKS DECOTI GRAPH BIHAR HAS THE MAXIMUM NUMBER OF DECATY AS COMPARED TO THE OTHER STATE
# 2.ACCORDING TO THE BANKS ROBBERY GRAPH MAHARASHTRA AND KARNATAKA HAS MAXIMUM NUMBER OF ROBBERY AS COMPARED TO THE OTHER STATE
# 3.ACCORDING TO THE BANK BURGLARY GRAPH MAHARASHTRA HAS MAXIMUM NUMBER OF BURGLARY AS COMPARED TO THE OTHER STATE
# 4.ACCORDING TO THE BANK THEFT GRAPH MAHARASHTRA HAS MAXIMUM NYMBER OF THEFT AS COMPARED TO THE OTHER STATE
# ALSO WE CAN SAY THAT IN ALL THE 4 GRAPH THE CRIMES HAPPEN IN THE STATES ARE MORE AS COMPARED TO THE UNION TERRITORIES

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='OTHER PLACES - Dacoity',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='OTHER PLACES - Dacoity', ylabel='STATE/UT'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='OTHER PLACES - Robbery',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='OTHER PLACES - Robbery', ylabel='STATE/UT'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='OTHER PLACES - Burglary',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='OTHER PLACES - Burglary', ylabel='STATE/UT'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='OTHER PLACES - Theft',y='STATE/UT',data=data)
# Out:
# <AxesSubplot:xlabel='OTHER PLACES - Theft', ylabel='STATE/UT'>

# %% [markdown]
# # OBSERVATION
# IN THE ABOVE 4 GRAPH THERE ARE MANY OBSERVATION
# 1.ACCORDING TO THE OTHER PLACES DECOTI GRAPH MAHYARASHTRA HAS THE MAXIMUM NUMBER OF DECATY AS COMPARED TO THE OTHER STATE
# 2.ACCORDING TO THE OTHER PLACES ROBBERY GRAPH MAHARASHTRA AND KARNATAKA HAS MAXIMUM NUMBER OF ROBBERY AS COMPARED TO THE OTHER STATE
# 3.ACCORDING TO THE OTHER PLACES BURGLARY GRAPH MAHARASHTRA HAS MAXIMUM NUMBER OF BURGLARY AS COMPARED TO THE OTHER STATE
# 4.ACCORDING TO THE OTHER PLACES THEFT GRAPH MAHARASHTRA HAS MAXIMUM NYMBER OF THEFT AS COMPARED TO THE OTHER STATE
# ALSO WE CAN SAY THAT IN ALL THE 4 GRAPH THE CRIMES HAPPEN IN THE STATES ARE MORE AS COMPARED TO THE UNION TERRITORIES

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='YEAR',y='TOTAL - Theft',data=data)
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='TOTAL - Theft'>

# %% [markdown]
# # OBSERVATION
# IN 2001 THE TOTAL THEFT IS ALMOST 20000 AND IN 2002 ITS ALMOST THE SAME AS 2001 BUT IN 2003 DECRESE TO AROUND 18000
# THEN AFTER 2003 THERE IS INCREASE IN THE TOTAL THEFT BUT IN 2008 THERE IS DECREASE UPTO 16000 AND AFTER 2008 THERE IS
# MASSIVE FALLDOWN 16000 BUT AFTER 2008 THERE IS MASSIVE INCREASE.
# ALSO WE CONCLUDE FROM THE GRAPH THAT AMONG ALL YEAR 2011 HAS THE MAXIMUM NUMBER OF THEFT

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='YEAR',y='TOTAL - Robbery',data=data)
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='TOTAL - Robbery'>

# %% [markdown]
# # OBSERVATION
# IN 2001 THE TOTAL ROBERRY IS ALMOST 17000 AND IN 2002 ITS ALMOST THE SAME AS 2001 BUT IN 2003 DECRESE TO AROUND 14000
# THEN AFTER 2003 THERE IS INCREASE IN THE TOTAL ROBBERY BUT IN 2008 THERE IS DECREASE FROM 17000 TO 9000 AND
# AFTER 2008 THERE IS MASSIVE INCREASE AFTER 2008.
# ALSO WE CONCLUDE FROM THE GRAPH THAT AMONG ALL YEAR 2012 HAS THE MAXIMUM NUMBER OF ROBERRY

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='YEAR',y='TOTAL - Burglary',data=data)
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='TOTAL - Burglary'>

# %% [markdown]
# # OBSERVATION
# IN 2001 THE TOTAL ROBERRY IS ALMOST 8000 AND IN 2002 ITS ALMOST THE SAME AS 2001 THAT IS 7900 BUT IN 2003 DECRESE TO
# AROUND 7700 AND IN 2005 ALSO THERE IS DECREASE 7500 BUT AFTER THAT THERE IS INCREASE IN 2006 AND 2007
# BUT IN 2008 THERE IS DECREASE FROM 8000 TO 4500 WHICH IS GOOD FOR OUR COUNTRY AND
# AFTER 2008 THERE IS MASSIVE INCREASE AS COMPARED TO 2008 WHICH IS NOT GOOD FOR OUR COUNTRY.
# ALSO WE CONCLUDE FROM THE GRAPH THAT AMONG ALL YEAR 2001 HAS THE MAXIMUM NUMBER OF BURGLARY

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='YEAR',y='TOTAL - Dacoity',data=data)
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='TOTAL - Dacoity'>

# %% [markdown]
# # OBSERVATION
# IN 2001 THE TOTAL DACOITY IS ALMOST 450 AND IN 2002 ITS ALMOST THE SAME AS 2001 OR A LITTLE BIT INCREASE
# THAT IS  520 BUT IN 2003 DECRESE
# AROUND 430 AND IN 2005 ALSO THERE IS DECREASE 385 BUT AFTER THAT THERE IS DECREASE IN 2006 AND 2007
# BUT IN 2008 THERE IS DECREASE FROM 450 TO 230 WHICH IS GOOD FOR OUR COUNTRY AND
# AFTER 2008 THERE IS INCREASE IN 2009 AS COMPARED TO 2008 WHICH IS NOT GOOD FOR OUR COUNTRY BUT AFTER 2009 THERE IS DECREASE
# AS COMPARED TO 2009
# ALSO WE CONCLUDE FROM THE GRAPH THAT AMONG ALL YEAR 2002 HAS THE MAXIMUM NUMBER OF BURGLARY

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='AREA(km2)',y='TOTAL - Dacoity',data=data)
# Out:
# <AxesSubplot:xlabel='AREA(km2)', ylabel='TOTAL - Dacoity'>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='AREA(km2)',y='TOTAL - Robbery',data=data)
# Out:
# <AxesSubplot:xlabel='AREA(km2)', ylabel='TOTAL - Robbery'>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='AREA(km2)',y='TOTAL - Burglary',data=data)
# Out:
# <AxesSubplot:xlabel='AREA(km2)', ylabel='TOTAL - Burglary'>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='AREA(km2)',y='TOTAL - Theft',data=data)
# Out:
# <AxesSubplot:xlabel='AREA(km2)', ylabel='TOTAL - Theft'>

# %% [markdown]
# # OBSERVATION
# BY SEEING ALL THE 4 GRAPH WE CAN CONCLUDE THE SEVERAL POINT
# 1.IN ALL THE 4 GRAPH MAXIMUM CRIME IS IN THE AREA BETWEEN 0.0-0.5 WHICH IS QUITE INTRESTING
# 2.ACCORDING TO FIRST GRAPH THAT IS TOTAL DECOITY WE CAN SEE THAT MAXIMUM CRIME RATE IS BETWEEN 0-1000 AND SOME ARE ABOVE 10000
#   THAT IS NEAR ABOUT 14000
# 3.SAME AS FOR ALL THE THREE GRAPH THE CRIME RATE IS IN THE AREA BETWEEN 0.0-0.5 WHETHER IT IS TOTAL THEFT,TOTAL ROBBERY ALL
#   THE CRIME RATE IS BETWEEN THAT AREA
# 4.ALSO I NOTICE THAT AS THE AREA INCREASES CRIME RATE ALSO INCREASES,LIKE BY LOOKING INTO ALL THE GRAPH WE CAN EASILY CONCLUDE
#   THAT AS THE AREA INCREASES CRIME RATE ALSO INCRESES AND THE MAXIMUM CRIME IS BETWEEN THE AREA 3.0-3.5 WHICH IS AGAIN
#    QUITE INTREATING.ALSO WE CAN SAYTHAT AS LONG AS AREA INCREASES AT THAT TIME CRIME RATE IS ON THE PEAK LEVEL WHICCH
#    IS NOT GOOD FOR THE COUNTRY AND ALSO FOR THE CITIZEN OF INDIA

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='RURAL POPULATION',y='TOTAL - Theft',data=data)
# Out:
# <AxesSubplot:xlabel='RURAL POPULATION', ylabel='TOTAL - Theft'>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='URBAN POPULATION',y='TOTAL - Theft',data=data)
# Out:
# <AxesSubplot:xlabel='URBAN POPULATION', ylabel='TOTAL - Theft'>

# %% [markdown]
# # OBSERVATION
# IN BOTH THE GRAPH WE CAN EASILY CONCLUDE THAT FOR BOTH RURAL AND URBAN POPULATION TOTAL THEFT IS AROUND 50000
# ALSO WE OBSERVE THAT AS THE POPULATION INCREASES CRIME ALSO INCREASES IN BOTH THE GRAPH AND THE CRIME RATE ALSO INCREASES
# THAT MEANS AS POPULATION INCREASES IN BOTH URBAN AND RURAL TOTAL CRIME INCREASES TO ITS MAXIMUM LIMIT.ALSO WE OBSERVE THAT MAXIMUM CRIME OCCUR BETWEEN 0-6 BUT AFTER THAT CRIME RATE DECREASES AND THE IS
# ON THE MAXIMUM LIMIT BUT IT IS MOST SATISFIED THAT VERY LESS POPULATION IS INVOLVED WHICH IS GOOD FOR THE COUNTRY

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='RURAL POPULATION',y='TOTAL - Dacoity',data=data)
# Out:
# <AxesSubplot:xlabel='RURAL POPULATION', ylabel='TOTAL - Dacoity'>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='URBAN POPULATION',y='TOTAL - Dacoity',data=data)
# Out:
# <AxesSubplot:xlabel='URBAN POPULATION', ylabel='TOTAL - Dacoity'>

# %% [markdown]
# # OBSERVATION
# IN BOTH THE GRAPH WE CAN EASILY CONCLUDE THAT FOR BOTH RURAL AND URBAN POPULATION TOTAL DAICOITY IS BETWEEN 0-2000
# ALSO WE OBSERVE THAT AS THE POPULATION INCREASES CRIME ALSO INCREASES IN BOTH THE GRAPH AND THE CRIME RATE ALSO INCREASES
# THAT MEANS AS POPULATION INCREASES IN BOTH URBAN AND RURAL TOTAL CRIME INCREASES TO ITS MAXIMUM LIMIT
# ALSO WE OBSERVE THAT MAXIMUM CRIME OCCUR BETWEEN 0-6 IN URBAN AND 0-1 IN RURAL BUT AFTER THAT CRIME RATE DECREASES AND THE IS
# NOT ON THE MAXIMUM LIMIT AND VERY LESS POPULATION INVOLVED WHICH IS GOOD FOR THE COUNTRY

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='URBAN POPULATION',y='TOTAL - Burglary',data=data)
# Out:
# <AxesSubplot:xlabel='URBAN POPULATION', ylabel='TOTAL - Burglary'>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='RURAL POPULATION',y='TOTAL - Burglary',data=data)
# Out:
# <AxesSubplot:xlabel='RURAL POPULATION', ylabel='TOTAL - Burglary'>

# %%
#OBSERVATION
IN BOTH THE GRAPH WE CAN EASILY CONCLUDE THAT FOR BOTH RURAL AND URBAN POPULATION TOTAL DAICOITY IS BETWEEN 0-20000
ALSO WE OBSERVE THAT AS THE POPULATION INCREASES CRIME ALSO INCREASES IN BOTH THE GRAPH AND THE CRIME RATE ALSO INCREASES
THAT MEANS AS POPULATION INCREASES IN BOTH URBAN AND RURAL TOTAL CRIME INCREASES TO ITS MAXIMUM LIMIT
ALSO WE OBSERVE THAT MAXIMUM CRIME OCCUR BETWEEN 0-1 IN RURALAND 0-6 IN URBAN BUT AFTER THAT CRIME RATE DECREASES AND THE IS 
NOT ON THE MAXIMUM LIMIT AND VERY LESS POPULATION INVOLVED WHICH IS GOOD FOR THE COUNTRY

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='RURAL POPULATION',y='TOTAL - Robbery',data=data)
# Out:
# <AxesSubplot:xlabel='RURAL POPULATION', ylabel='TOTAL - Robbery'>

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='URBAN POPULATION',y='TOTAL - Robbery',data=data)
# Out:
# <AxesSubplot:xlabel='URBAN POPULATION', ylabel='TOTAL - Robbery'>

# %% [markdown]
# # OBSERVATION
# IN BOTH THE GRAPH WE CAN EASILY CONCLUDE THAT FOR BOTH RURAL AND URBAN POPULATION TOTAL DAICOITY IS BETWEEN 0-5000
# ALSO WE OBSERVE THAT AS THE POPULATION INCREASES CRIME ALSO INCREASES IN BOTH THE GRAPH AND THE CRIME RATE ALSO INCREASES
# THAT MEANS AS POPULATION INCREASES IN BOTH URBAN AND RURAL TOTAL CRIME INCREASES TO ITS MAXIMUM LIMIT
# ALSO WE OBSERVE THAT MAXIMUM CRIME OCCUR BETWEEN 0-0.8 IN RURAL AND 0-6 IN URBAN BUT AFTER THAT CRIME RATE DECREASES AND THE IS
# NOT ON THE MAXIMUM LIMIT AND VERY LESS POPULATION INVOLVED WHICH IS GOOD FOR THE COUNTRY
